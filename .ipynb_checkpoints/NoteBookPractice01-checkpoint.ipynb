# %%
import numpy as np
import pandas as pd

# %%
practice0 = pd.DataFrame({"이름": ["홍길동","김길동"], "나이":[100,200]})

# %%
practice0
# Out:
#     이름   나이
# 0  홍길동  100
# 1  김길동  200

# %%
practice = pd.DataFrame({"날짜":[], "운동":[], "양":[]})
practice
# Out:
# Empty DataFrame
# Columns: [날짜, 운동, 양]
# Index: []

# %%
# loc[행인덱스] => 행 인덱스에 한 행을 추가하라
practice.loc[0] = ['19-3-1', '달리기', '1.']

# %%
practice
# Out:
#        날짜   운동   양
# 0  19-3-1  달리기  1.

# %%
practice.loc[1] = ['19-3-2', '걷기', '1.']
practice.loc[2] = ['19-3-2', '달리기', '2.']
practice.loc[3] = ['19-3-2', '계단오르기', '3.']
practice
# Out:
#        날짜     운동   양
# 0  19-3-1    달리기  1.
# 1  19-3-2     걷기  1.
# 2  19-3-2    달리기  2.
# 3  19-3-2  계단오르기  3.

# %%
practice.loc[4] = ['19-3-3', '걷기', '2.5']
practice.loc[5] = ['19-3-3', '달리기', '3.1']
practice
# Out:
#        날짜     운동    양
# 0  19-3-1    달리기   1.
# 1  19-3-2     걷기   1.
# 2  19-3-2    달리기   2.
# 3  19-3-2  계단오르기   3.
# 4  19-3-3     걷기  2.5
# 5  19-3-3    달리기  3.1

# %%
practice.to_csv('data/practice/practice2.csv', encoding='utf-8')
# Kaggle 에서는 readonly이기 때문에 저장이 안됨

# %%
# index-col=0을 하면 오토 인덱싱을 하지 않습니다.
practice2 = pd.read_csv('data/practice.csv', index_col=0, encoding='utf-8')

# %%
practice2.loc[6] = ['19-3-4', '걷기', 1.5]
practice2.loc[7] = ['19-3-5', '달리기', 1.]
practice2.loc[8] = ['19-3-6', '걷기', 2.5]
practice2.loc[9] = ['19-3-7', '달리기', 0.5]
practice2
# Out:
#        날짜     운동    양
# 0  19-3-1    달리기  1.0
# 1  19-3-2     걷기  1.0
# 2  19-3-2    달리기  1.0
# 3  19-3-2  계단오르기  1.0
# 4  19-3-3     걷기  1.5
# 5  19-3-3    달리기  1.0
# 6  19-3-4     걷기  1.5
# 7  19-3-5    달리기  1.0
# 8  19-3-6     걷기  2.5
# 9  19-3-7    달리기  0.5

# %%
# default는 평균이다
practice2.pivot_table(index='운동')
# Out:
#            양
# 운동
# 걷기     1.625
# 계단오르기  1.000
# 달리기    0.900

# %%
practice2.pivot_table(index='운동', aggfunc=np.sum)
# Out:
#          양
# 운동
# 걷기     6.5
# 계단오르기  1.0
# 달리기    4.5

# %%
practice2.pivot_table(index='운동', aggfunc=[np.sum, np.average,len])
# Out:
#        sum average len
#          양       양  날짜    양
# 운동
# 걷기     6.5   1.625   4  4.0
# 계단오르기  1.0   1.000   1  1.0
# 달리기    4.5   0.900   5  5.0

# %%
prac_pivot = practice2.pivot('날짜', '운동', '양')
#                        인덱스(행), 종류(열), 데이터(가운데 채워지는 값)
prac_pivot
# Out:
# 운동       걷기  계단오르기  달리기
# 날짜
# 19-3-1  NaN    NaN  1.0
# 19-3-2  1.0    1.0  1.0
# 19-3-3  1.5    NaN  1.0
# 19-3-4  1.5    NaN  NaN
# 19-3-5  NaN    NaN  1.0
# 19-3-6  2.5    NaN  NaN
# 19-3-7  NaN    NaN  0.5

# %%
#NaN : 행과 열에 적합한 값이 없다 => 삭제, 수치로 변환
# 수치변환: 평균, 0, 기본값으로 변환

# %%
prac_pivot.fillna(0, inplace=True) # inplace=True: 비파괴함수-> 파괴함수(변경된 부분이 원본에 반영이 되도록 설정)
prac_pivot
# Out:
# 운동       걷기  계단오르기  달리기
# 날짜
# 19-3-1  0.0    0.0  1.0
# 19-3-2  1.0    1.0  1.0
# 19-3-3  1.5    0.0  1.0
# 19-3-4  1.5    0.0  0.0
# 19-3-5  0.0    0.0  1.0
# 19-3-6  2.5    0.0  0.0
# 19-3-7  0.0    0.0  0.5

# %%
type(prac_pivot)
# Out:
# pandas.core.frame.DataFrame

# %%
not_excercise = pd.read_excel('data/practice/reason_not_exercise.xls')
not_excercise.head(20)
# Out:
#       기간    대분류            분류  운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  \
# 0   2017    서울시           서울시               49.7              8.1
# 1   2017     성별            남자               55.2              7.9
# 2   2017     성별            여자               45.0              8.3
# 3   2017    연령별           10대               55.7              6.1
# 4   2017    연령별           20대               54.8              6.9
# 5   2017    연령별           30대               58.1              5.5
# 6   2017    연령별           40대               57.7              6.8
# 7   2017    연령별           50대               50.1              9.2
# 8   2017    연령별        60대 이상               27.5             12.8
# 9   2017    학력별         중졸 이하               26.1             13.7
# 10  2017    학력별         고졸 이하               46.3              8.5
# 11  2017    학력별         대졸 이하               57.4              6.6
# 12  2017    학력별        대학원 이상               65.3              3.8
# ...

# %%
not_excercise.drop(columns='기간', inplace=True)

# %%
not_excercise.drop(index=range(22,53), inplace=True)
not_excercise.shape
# Out:
# (22, 7)

# %%
not_excercise
# Out:
#       대분류            분류  운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 0     서울시           서울시               49.7              8.1               5.8
# 1      성별            남자               55.2              7.9               5.5
# 2      성별            여자               45.0              8.3               6.0
# 3     연령별           10대               55.7              6.1               5.6
# 4     연령별           20대               54.8              6.9               5.2
# 5     연령별           30대               58.1              5.5               4.6
# 6     연령별           40대               57.7              6.8               5.2
# 7     연령별           50대               50.1              9.2               7.2
# 8     연령별        60대 이상               27.5             12.8               6.9
# 9     학력별         중졸 이하               26.1             13.7               6.6
# 10    학력별         고졸 이하               46.3              8.5               6.9
# ...

# %%
not_excercise['대분류'].unique()
# Out:
# array(['서울시', '성별', '연령별', '학력별', '소득별', '혼인상태별'], dtype=object)

# %%
not_excercise['대분류'] == '성별'#브로드캐스팅
# Out:
# 0     False
# 1      True
# 2      True
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# Name: 대분류, dtype: bool

# %%
not_excercise[not_excercise['대분류'] == '성별']
# Out:
#   대분류  분류  운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서   기타
# 1  성별  남자               55.2              7.9               5.5      29.8  1.6
# 2  성별  여자               45.0              8.3               6.0      38.8  1.8

# %%
not_ex_sex = not_excercise[not_excercise['대분류'] == '성별'].copy()   #깊은복사

# %%
not_ex_sex
# Out:
#   대분류  분류  운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서   기타
# 1  성별  남자               55.2              7.9               5.5      29.8  1.6
# 2  성별  여자               45.0              8.3               6.0      38.8  1.8

# %%
not_ex_sex.drop(columns='대분류', inplace=True)

# %%
not_ex_sex.set_index('분류', inplace=True)#index 설정

# %%
not_ex_sex
# Out:
#     운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서   기타
# 분류
# 남자               55.2              7.9               5.5      29.8  1.6
# 여자               45.0              8.3               6.0      38.8  1.8

# %%
import matplotlib.pyplot as plt

# %%
from matplotlib import font_manager, rc # 한글 처리

# %%
f_path = 'C:/Windows/Fonts/malgun.ttf'
font_name=font_manager.FontProperties(fname=f_path).get_name()
rc('font', family = font_name)

# %%
plt.rcParams['axes.unicode_minus'] = False

# %%
def call():
    return 100,200
print(call())
# Out:
# (100, 200)

# %%
x, y = call()
print(x, y)
# Out:
# 100 200

# %%
f,ax = plt.subplots(1, 2, figsize = (16,8))
not_ex_sex['운동을 할 충분한 시간이 없어서'].plot.pie(explode=[0, 0.02], ax=ax[0], autopct='%1.1f%%')
not_ex_sex['함께 운동을 할 사람이 없어서'].plot.pie(explode=[0, 0.02], ax=ax[1], autopct='%1.1f%%')
ax[0].set_title('운동할 시간이 없음')
ax[1].set_title('운동할 사람이 없음')
plt.show()

# %%
not_excercise['대분류'].unique()
# Out:
# array(['서울시', '성별', '연령별', '학력별', '소득별', '혼인상태별'], dtype=object)

# %%
not_ex_age = not_excercise[not_excercise['대분류'] == '연령별'].copy()
not_ex_money = not_excercise[not_excercise['대분류'] == '소득별'].copy()
not_ex_age
# Out:
#    대분류      분류  운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 3  연령별     10대               55.7              6.1               5.6
# 4  연령별     20대               54.8              6.9               5.2
# 5  연령별     30대               58.1              5.5               4.6
# 6  연령별     40대               57.7              6.8               5.2
# 7  연령별     50대               50.1              9.2               7.2
# 8  연령별  60대 이상               27.5             12.8               6.9
#
#    운동을 싫어해서   기타
# 3      32.2  0.3
# 4      32.9  0.1
# 5      31.6  0.2
# 6      29.4    1
# 7      32.2  1.4
# 8      46.8    6

# %%
not_ex_money
# Out:
#     대분류            분류  운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 13  소득별      100만원 미만               22.7             10.3               3.6
# 14  소득별  100-200만원 미만               34.3             11.5               7.1
# 15  소득별  200-300만원 미만               48.8             12.3               6.8
# 16  소득별  300-400만원 미만               54.9              7.1               6.5
# 17  소득별  400-500만원 미만               56.1                5               5.3
# 18  소득별      500만원 이상               52.3              7.1               5.1
#
#     운동을 싫어해서    기타
# 13      50.7  12.7
# 14      41.5   5.6
# 15      30.7   1.4
# 16      31.2   0.3
# 17      33.0   0.6
# 18      34.9   0.6

# %%
not_ex_age.drop(columns='대분류', inplace=True)
not_ex_money.drop(columns='대분류', inplace=True)
not_ex_age
# Out:
#        분류  운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서   기타
# 3     10대               55.7              6.1               5.6      32.2  0.3
# 4     20대               54.8              6.9               5.2      32.9  0.1
# 5     30대               58.1              5.5               4.6      31.6  0.2
# 6     40대               57.7              6.8               5.2      29.4    1
# 7     50대               50.1              9.2               7.2      32.2  1.4
# 8  60대 이상               27.5             12.8               6.9      46.8    6

# %%
not_ex_money
# Out:
#               분류  운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  \
# 13      100만원 미만               22.7             10.3               3.6
# 14  100-200만원 미만               34.3             11.5               7.1
# 15  200-300만원 미만               48.8             12.3               6.8
# 16  300-400만원 미만               54.9              7.1               6.5
# 17  400-500만원 미만               56.1                5               5.3
# 18      500만원 이상               52.3              7.1               5.1
#
#     운동을 싫어해서    기타
# 13      50.7  12.7
# 14      41.5   5.6
# 15      30.7   1.4
# 16      31.2   0.3
# 17      33.0   0.6
# 18      34.9   0.6

# %%
not_ex_age.set_index('분류', inplace=True)
not_ex_money.set_index('분류', inplace=True)
not_ex_age
# Out:
#         운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서   기타
# 분류
# 10대                  55.7              6.1               5.6      32.2  0.3
# 20대                  54.8              6.9               5.2      32.9  0.1
# 30대                  58.1              5.5               4.6      31.6  0.2
# 40대                  57.7              6.8               5.2      29.4    1
# 50대                  50.1              9.2               7.2      32.2  1.4
# 60대 이상               27.5             12.8               6.9      46.8    6

# %%
not_ex_money
# Out:
#               운동을 할 충분한 시간이 없어서 함께 운동을 할 사람이 없어서  운동을 할 만한 장소가 없어서  운동을 싫어해서  \
# 분류
# 100만원 미만                   22.7             10.3               3.6      50.7
# 100-200만원 미만               34.3             11.5               7.1      41.5
# 200-300만원 미만               48.8             12.3               6.8      30.7
# 300-400만원 미만               54.9              7.1               6.5      31.2
# 400-500만원 미만               56.1                5               5.3      33.0
# 500만원 이상                   52.3              7.1               5.1      34.9
#
#                 기타
# 분류
# 100만원 미만      12.7
# 100-200만원 미만   5.6
# 200-300만원 미만   1.4
# 300-400만원 미만   0.3
# 400-500만원 미만   0.6
# 500만원 이상       0.6

# %%
f,ax = plt.subplots(2, 2, figsize = (10,10))
#f라는 참조형 큰 틀에 ax배열을 하나씩 넣어줌, ax는 nd array임
not_ex_age['운동을 할 충분한 시간이 없어서'].plot.pie(explode=[0.1, 0.02, 0.02, 0.02, 0.02, 0.02], ax=ax[0][0], autopct='%1.1f%%')
not_ex_age['함께 운동을 할 사람이 없어서'].plot.pie(explode=[0.1, 0.02, 0.02, 0.02, 0.02, 0.02], ax=ax[0][1], autopct='%1.1f%%')
not_ex_money['운동을 할 충분한 시간이 없어서'].plot.pie(explode=[0.1, 0.02, 0.02, 0.02, 0.02, 0.02], ax=ax[1][0], autopct='%1.1f%%')
not_ex_money['함께 운동을 할 사람이 없어서'].plot.pie(explode=[0.1, 0.02, 0.02, 0.02, 0.02, 0.02], ax=ax[1][1], autopct='%1.1f%%')
ax[0][0].set_title('연령별 운동할 시간이 없음')
ax[0][1].set_title('연령별 운동할 사람이 없음')
ax[1][0].set_title('소득별 운동할 시간이 없음')
ax[1][1].set_title('소득별 운동할 사람이 없음')
plt.show()
