# %%
import pandas as pd
import numpy as np

# %%
#df = pd.read_csv('../data/서울시 5대 범죄 발생현황 통계.txt', encoding='utf-8', delimiter = '\t',engine='python')
#df

# %%
df1 = pd.read_csv('../data/서울시 주말휴일 여가활동 통계19~20.txt', encoding='utf-8', delimiter="\t", engine='python')
df1
# Out:
#        기간    대분류            분류  영상시청  여행야외나들이  컴퓨터게임인터넷검색 등    휴식  사회봉사활동  \
# 0    2019    서울시           서울시  24.5     20.9           8.1   2.3     2.6
# 1    2019     성별            남자  24.3     20.4           9.6   2.3     2.3
# 2    2019     성별            여자  24.8     21.4           6.7   2.2     2.9
# 3    2019    연령별           10대  19.1     13.1          24.2   0.7     3.4
# 4    2019    연령별           20대  17.3     21.3          15.5   1.6     3.1
# 5    2019    연령별           30대  18.8     29.1           9.4   2.0     1.9
# 6    2019    연령별           40대  22.6     24.9           6.6   1.6     2.0
# 7    2019    연령별           50대  26.1     19.9           5.2   2.6     2.4
# 8    2019    연령별        60대 이상  35.1     14.3           1.8   3.5     3.2
# 9    2019    학력별         중졸 이하  38.5     12.1           3.4   4.8     4.0
# 10   2019    학력별         고졸 이하  28.6     18.2           8.2   2.1     2.3
# 11   2019    학력별         대졸 이하  19.1     24.5           9.3   1.7     2.5
# ...

# %%
df2 = pd.read_csv('../data/서울시 주말휴일 여가활동 통계16~18.txt', encoding='utf-8', delimiter="\t", engine='python')
df2
# Out:
#        기간    대분류            분류   합계  TV  또는 비디오시청  여행야외나들이  컴퓨터게임인터넷검색 등   휴식  \
# 0    2016    서울시           서울시  100          43.0     13.2           6.9  6.5
# 1    2016     성별            남자  100          43.7     13.1           7.6  6.0
# 2    2016     성별            여자  100          42.4     13.2           6.3  7.0
# 3    2016    연령별           10대  100          52.5     12.8           2.1  5.6
# 4    2016    연령별           20대  100          50.1     15.1           3.5  5.3
# 5    2016    연령별           30대  100          42.4     15.6           5.3  5.3
# 6    2016    연령별           40대  100          38.3     16.0           9.8  6.7
# 7    2016    연령별           50대  100          44.7     10.7           8.6  7.8
# 8    2016    연령별        60대 이상  100          38.6      9.5           8.3  7.4
# 9    2016    학력별         중졸 이하  100          39.3      9.9           7.8  8.1
# 10   2016    학력별         고졸 이하  100          42.8     12.5           7.6  6.7
# ...
